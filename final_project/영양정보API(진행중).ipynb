# %%
import requests, bs4
import pandas as pd
from lxml import html
from urllib.request import Request, urlopen
from urllib.parse import urlencode, quote_plus, unquote, urlparse
import xml.etree.ElementTree as ET
import urllib.request
from pandas import json_normalize
import json

from requests.models import Response
apiKey = unquote('4DJ1VQS4ddl8Atjq1OljTLSkAEhOCTNcyxydHBiR%2FTsJmBUI2SRnDbfoQkxx8Y4GudA67W0poAc%2BuqULvv2Jgw%3D%3D')
url = 'http://apis.data.go.kr/1471000/FoodNtrIrdntInfoService1/getFoodNtrItdntList1'

# pageNo의 max값 :227
n = 1
for n in range(2):
    queryParams = '?' + urlencode({ quote_plus('ServiceKey') : apiKey,
                                   quote_plus('pageNo') : n,
                                   quote_plus('numOfRows') : '100',
                                   quote_plus('type') : 'json'})
    

    result = requests.get(urlparse(url + queryParams).geturl(), headers = {'User-Agent': 'Mozilla/5.0'})
    json_obj = result.json()
    temp_data = json.dumps(json_obj['body'])
    json_data = json.loads(temp_data)
    df = pd.Series(json_data)

df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:28: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
# pageNo                                                        1
# totalCount                                                22602
# numOfRows                                                   100
# items         [{'DESC_KOR': '고량미,알곡', 'SERVING_WT': '0', 'NU...
# dtype: object

# %%
temp_data = json.dumps(json_obj['body'])
temp_data['items']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-69-c5b085c83e3e> in <module>()
#       1 temp_data = json.dumps(json_obj['body'])
# ----> 2 temp_data['items']
#
# TypeError: string indices must be integers

# %%
# temp_data['items']
import numpy
a = df.values[1]
b = df.values.tolist()

array_df = pd.DataFrame(b)

# %%
array_df
# Out:
#     0      1    2                                                  3
# 0   1  22602  100  {'DESC_KOR': '고량미,알곡', 'SERVING_WT': '0', 'NUT...
# 1   1  22602  100  {'DESC_KOR': '겉귀리,생것', 'SERVING_WT': '100', 'N...
# 2   1  22602  100  {'DESC_KOR': '겉귀리,생것', 'SERVING_WT': '100', 'N...
# 3   1  22602  100  {'DESC_KOR': '쌀귀리,생것', 'SERVING_WT': '100', 'N...
# 4   1  22602  100  {'DESC_KOR': '쌀귀리,생것', 'SERVING_WT': '100', 'N...
# .. ..    ...  ...                                                ...
# 95  1  22602  100  {'DESC_KOR': '곰보빵', 'SERVING_WT': '100', 'NUTR...
# 96  1  22602  100  {'DESC_KOR': '곰보빵', 'SERVING_WT': '100', 'NUTR...
# 97  1  22602  100  {'DESC_KOR': '도우넛,링', 'SERVING_WT': '100', 'NU...
# 98  1  22602  100  {'DESC_KOR': '도우넛,링', 'SERVING_WT': '100', 'NU...
# 99  1  22602  100  {'DESC_KOR': '도우넛,이스트', 'SERVING_WT': '70', 'N...
#
# [100 rows x 4 columns]

# %%
array_df2 = array_df.drop([0,1,2],axis=1)

# %%
array_df2.columns = ['item']
array_df2
# Out:
#                                                  item
# 0   {'DESC_KOR': '고량미,알곡', 'SERVING_WT': '0', 'NUT...
# 1   {'DESC_KOR': '겉귀리,생것', 'SERVING_WT': '100', 'N...
# 2   {'DESC_KOR': '겉귀리,생것', 'SERVING_WT': '100', 'N...
# 3   {'DESC_KOR': '쌀귀리,생것', 'SERVING_WT': '100', 'N...
# 4   {'DESC_KOR': '쌀귀리,생것', 'SERVING_WT': '100', 'N...
# ..                                                ...
# 95  {'DESC_KOR': '곰보빵', 'SERVING_WT': '100', 'NUTR...
# 96  {'DESC_KOR': '곰보빵', 'SERVING_WT': '100', 'NUTR...
# 97  {'DESC_KOR': '도우넛,링', 'SERVING_WT': '100', 'NU...
# 98  {'DESC_KOR': '도우넛,링', 'SERVING_WT': '100', 'NU...
# 99  {'DESC_KOR': '도우넛,이스트', 'SERVING_WT': '70', 'N...
#
# [100 rows x 1 columns]

# %%
json_normalize(array_df2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-89-dc527c11e017> in <module>()
# ----> 1 json_normalize(array_df2)
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/json/_normalize.py in _json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     271             # naive normalization, this is idempotent for flat records
#     272             # and potentially will inflate the data considerably for
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/json/_normalize.py in <genexpr>(.0)
#     268
#     269     if record_path is None:
# --> 270         if any([isinstance(x, dict) for x in y.values()] for y in data):
#     271             # naive normalization, this is idempotent for flat records
#     272             # and potentially will inflate the data considerably for
#
# AttributeError: 'str' object has no attribute 'values'
